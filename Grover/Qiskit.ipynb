# %% [markdown]
# # **Qiskit**

# %% [markdown]
# # Construção Básica de Circuito Quântico

# %% [markdown]
# ```python
# # instalação dos pacotes
# !pip install qiskit matplotlib qiskit[visualization]
# ```

# %%
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler    # para fazer o teste
from qiskit.quantum_info import Statevector         # obter os estados
from qiskit.visualization import plot_bloch_multivector
import numpy as np

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.measure_all()
 
sampler = StatevectorSampler()
result = sampler.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())
# Out:
# {'11': 502, '00': 522}

# %%
from qiskit.visualization import plot_histogram
 
counts = result[0].data.meas.get_counts()
plot_histogram(counts)
 
# Include the next line if you are not using Python in a Jupyter notebook
# plt.show()
